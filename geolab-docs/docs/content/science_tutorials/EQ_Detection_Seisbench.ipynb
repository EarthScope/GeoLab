# %% [markdown]
# # Earthquake Detection Using Seisbench

# %% [markdown]
# In recent years, seismology has significantly benefited from machine learning (ML), which enhances efficiency, accuracy, and scope in earthquake detection. ML automates vast data processing, reducing manual effort and enabling real-time monitoring. It improves detection accuracy by recognizing patterns and anomalies often missed by traditional methods. ML models are adaptable and scalable, suitable for various regions and capable of analyzing global seismic data simultaneously. This notebook demonstrates the integration of Seisbench a common package used for ML studies, into an earthquake detection workflow.
#
# - [Seisbench Documentation](https://github.com/seisbench/seisbench)
# - [PhaseNet Documentation](https://github.com/AI4EPS/PhaseNet)
# - [PyOcto Documentation](https://github.com/yetinam/pyocto)
#
# This notebook also leverages **parallel processing**, a method that allows multiple computations to be carried out simultaneously, significantly speeding up data analysis by utilizing multiple CPU cores concurrently.
#
# **Author:** Marc Garcia, University of Texas - El Paso, magarcia58@miners.utep.edu

# %%
#Check for correct Image (GeoLab)
# !printenv | grep IMAGE
# Out:
# JUPYTER_IMAGE=public.ecr.aws/earthscope-dev/geolab:td-dev-dd5851e6
# DASK_GATEWAY__CLUSTER__OPTIONS__IMAGE={JUPYTER_IMAGE_SPEC}
# JUPYTER_IMAGE_SPEC=public.ecr.aws/earthscope-dev/geolab:td-dev-dd5851e6

# %%
# intall necessary packages for notebook
# !pip install seisbench 
# !pip install pyocto

# %% [markdown]
# # 1. Select Region of Interest(Cascadia Subduction Zone)
#
# The Cascadia Subduction Zone is a major fault line stretching from northern California to British Columbia, where the Juan de Fuca Plate is subducting beneath the North American Plate. This region is known for producing significant seismic activity, including potential megathrust earthquakes.
#
# For this study, we chose the UW (University of Washington) seismic network, which is ideal for testing and demonstrating our machine learning-based earthquake detection workflow. This demo is centered around the recent **magnitude 6.4 earthquake that occurred on July 11, 2024**, approximately 120 miles off Vancouver Island. This earthquake, the largest in a recent series of quakes, highlights the active seismic nature of the Cascadia region.
#
# We start by developing a station list by pulling in stations within the defined geographic bounds of the Cascadia Subduction Zone using the ObsPy library. The following code snippet defines the client and geographic bounds, sets the time range for active channels in 2024, and fetches station metadata for the PNSN network (UW) with the desired channels.

# %%
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# Define the client and geographic bounds of the Cascadia Subduction Zone
client = Client("IRIS")
min_latitude = 40.0
max_latitude = 50.0
min_longitude = -125.0
max_longitude = -120.0

# Define the time range for active channels in 2024
starttime = UTCDateTime('2024-01-01')
endtime = UTCDateTime('2024-12-31')

# Fetch station metadata within the defined region for the PNSN network UW, with desired channels
inv = client.get_stations(network="UW", station="*", location="*", channel="HH*", 
                                minlatitude=min_latitude, maxlatitude=max_latitude,
                                minlongitude=min_longitude, maxlongitude=max_longitude,
                                starttime=starttime, endtime=endtime, level="response")

print(inv)
# Out:
# Inventory created at 2024-07-25T00:46:28.018200Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2024-01-...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			UW
# 		Stations (131):
# 			UW.ABER (Abernathy Mountain, Cowlitz County, WA, USA)
# 			UW.ANGUS (Elk Ridge Ranch, WA, USA)
# 			UW.ARTIC (Weyerhaeuser Tree Farm, Grays Harbor County, WA, USA)
# 			UW.ASR2 (Mt. Adams - Stagman Ridge, WA, USA)
# 			UW.BABR (Baber Butte, OR, USA)
# 			UW.BBO (Butler Butte, OR, USA)
# 			UW.BDGR (Fisse-Smith Property, Kittitas, WA, USA)
# 			UW.BHAM (Bellingham, WA, USA)
# 			UW.BHW (Bald Hill, WA, USA)
# 			UW.BICK (Bickleton Ranch,Bickleton, WA, USA)
# 			UW.BLOB (Calvert Residence, Oakville, WA, USA)
# 			UW.BLOW (BLOW, Detroit Lake, OR, USA)
# 			UW.BOIS (Boistfort Consolidated School, Curtis, WA, USA)
# 			UW.BRO (Big Rock Lookout, OR, USA)
# 			UW.BST09 (BEST site 09, Seattle, WA, USA)
# 			UW.BUCKS (Joyce, WA, USA)
# 			UW.CBS (Chelan Butte South, WA, USA)
# 			UW.CDF (Cedar Flats, MSH, WA, USA)
# 			UW.CHIMA (Chimacum High School, Chimacum, WA, USA)
# 			UW.CINE (Cinebar, WA, USA)
# 			UW.CORE (Aberdeen, WA, USA)
# 			UW.COWL (Weyerhaeuser Mt St Helens Tree Farm, Lewis County, WA, USA)
# 			UW.COWS (Carnation, WA, USA)
# 			UW.COYL (Quilcene, WA, USA)
# 			UW.CROWN (Crown Point, Clallam County, WA, USA)
# 			UW.DART (Darrington, WA, USA)
# 			UW.DEAL (Weyerhaeuser Tree Farm, Grays Harbor County, WA, USA)
# 			UW.DONK (DONK, Steam Donkey, Weyerhauser Land)
# 			UW.DOORS (McCleary Water Tower Complex, McCleary, WA, USA)
# 			UW.DOSE (Dosewallips, Brinnon, WA, USA)
# 			UW.DOTY (Weyerhaeuser Tree Farm, Grays Harbor County, WA, USA)
# 			UW.EAGLE (Pioneer Elementary School, Shelton, WA, USA)
# 			UW.EDM (East Dome, Mt. St. Helens, WA, USA)
# 			UW.EQUIL (East Quilcene, WA, USA)
# 			UW.ETW (Entiat, WA, USA)
# 			UW.FISH2 (Jewell, OR, USA)
# 			UW.FMW (Mt. Fremont, WA, USA)
# 			UW.FORK (Forks, WA, USA)
# 			UW.GIGA (Grayland Intergalactic Airport, Grayland, WA, USA)
# 			UW.GNW (Green Mountain, WA, USA)
# 			UW.GOLDN (Goldendale, WA, USA)
# 			UW.GUEM (Guemes Island, WA, USA)
# 			UW.HANS (Far Echo Farms, Hansville, WA, USA)
# 			UW.HDW (Hoodsport, WA, USA)
# 			UW.HERD (Green Diamond Tree Farm, Grays Harbor County, WA, USA)
# 			UW.HILL (La Conner, WA, USA)
# 			UW.HOOD (Hood Meadows Ski Resort, Mt. Hood, OR, USA)
# 			UW.HOPR (Tall Timber Ranch, Leavenworth, WA, USA)
# 			UW.HOQUI (City of Hoquiam Watershed, Hoquiam, WA, USA)
# 			UW.HSR (South Ridge, Mt. St. Helens, WA, USA)
# 			UW.HTW (Haystack Lookout, WA, USA)
# 			UW.INGAL (Weyerhaeuser Pe Ell Tree Farm, Lewis County, WA, USA)
# 			UW.JEDS (Smith River, Reedsport, OR, USA)
# 			UW.KALA (American Forest Management Tree Farm, Kalaloch, WA, USA)
# 			UW.KENT (Carlson Farm, Grass Valley, OR, USA)
# 			UW.KNGST (Kingston, WA, USA)
# 			UW.KREP (White Salmon, WA, USA)
# 			UW.KTSAP (Belfair, WA, USA)
# 			UW.LACKA (Lackamas Elementary School, Yelm, WA, USA)
# 			UW.LCCR (Clarks, OR, USA)
# 			UW.LEID (Weyerhaeuser Tree Farm, Grays Harbor County, WA, USA)
# 			UW.LOKMT (Lookout Mt, WA, USA)
# 			UW.LON (Longmire, WA, USA)
# 			UW.LOPEZ (Johns Point, Lopez Island, WA, USA)
# 			UW.LRIV (Port Angeles, WA, USA)
# 			UW.LTY (Liberty Mine, WA, USA)
# 			UW.LUMI (Lummi Island, WA, USA)
# 			UW.MANO (Manastash Observatory, WA, USA)
# 			UW.MAPLE (Celestial Japanese Maples, Gig Harbor, WA, USA)
# 			UW.MBW2 (Mt Baker West 2, WA, USA)
# 			UW.MEW (McNeil Island, WA, USA)
# 			UW.MONTE (Montesano Tree Farm, Montesano, WA, USA)
# 			UW.MOODY (Moody Rd Farm, Hoquiam, WA, USA)
# 			UW.MOON (Moon Mt, OR, USA)
# 			UW.MORSE (Bainbridge, WA, USA)
# 			UW.MOX (Moxie City, WA, USA)
# 			UW.MULN (Lyman, WA, USA)
# 			UW.NATEM (Natembea Northwest Farm, Port Townsend, WA, USA)
# 			UW.NCO (Newberry Crater, OR, USA)
# 			UW.NEL (Nelson Butte, WA, USA)
# 			UW.NEMA (NEMA Site, Pacific County, WA, USA)
# 			UW.ODUC (Sol Duc Hot Springs, Olympic National Park, WA, US)
# 			UW.OHOH (Hoh Rainforest, Olympic National Park, WA, USA)
# 			UW.OLGA (Olga, Orcas Island, WA, USA)
# 			UW.OLQN (Olympic Peninsula, Lake Quinault, WA, USA)
# 			UW.OQNOB (Black Knob, Quinault Indian Nation, WA, USA)
# 			UW.OSQM (Golbeck Ranch, Sequim, WA, USA)
# 			UW.OSR (Salmon Ridge Lookout, Quinault Tribal Lands, WA, USA)
# 			UW.OTR (Olympic Penninsula - Tyee Ridge, WA, USA)
# 			UW.PAN4H (Panhandle 4H Camp, Shelton, WA, USA)
# 			UW.PASS (Maple Falls, WA, USA)
# 			UW.PRIN (Pacific Rim Institute, Coupeville, WA, USA)
# 			UW.RADR (Radar Ridge, Naselle, WA)
# 			UW.RATT (Rattlesnake Lake, King County, WA)
# 			UW.RCM (Camp Muir, Mount Rainier, WA, USA)
# 			UW.RER (Emerald Ridge, Mount Rainier, WA, USA)
# 			UW.RNWY (Roche Harbor Airport, San Juan Island, WA, USA)
# 			UW.RPW2 (Rockport, WA, USA)
# 			UW.SALO (Clinton, WA, USA)
# 			UW.SAXON (Nesset Farm, Saxon, WA, USA)
# 			UW.SEAS2 (Gearhart, OR, USA)
# 			UW.SHUK (Shuksan (Mt. Baker Ski Area), WA, USA)
# 			UW.SHW (Mt. St. Helens West, WA, USA)
# 			UW.SKAMO (SKAMO Site, Wahkiakum County, WA, USA)
# 			UW.SKOKO (Rock Peak, WA, USA)
# 			UW.SLDQ (Solduck, Olympic Peninsula, WA, USA)
# 			UW.SLF (Sugar Loaf, WA, USA)
# 			UW.SNAG (Snag Peak, Clallam County, WA, USA)
# 			UW.SP2 (Seward Park, Seattle, WA, USA)
# 			UW.SSO2 (House Mountain, OR, USA)
# 			UW.STOR (Enumclaw, WA, USA)
# 			UW.TBLMT (Table Mt, Ellensburg, WA, USA)
# 			UW.TDH (Tom,Dick,Harry Mt., OR, USA)
# 			UW.TKEY (Lakebay, WA, USA)
# 			UW.TOLE (Toledo High School, WA, USA)
# 			UW.TOLT (Tolt Reservoir, WA, USA)
# 			UW.TOUT (Weyerhaeuser Mt St Helens Tree Farm, Cowlitz County, WA, USA)
# 			UW.TREE (Summer Lake, OR, USA)
# 			UW.TURTL (Turtleback Complex, Orcas Island, WA, USA)
# 			UW.TWISP (Winthrop, WA, USA)
# 			UW.VFP (Flag Point, OR, USA)
# 			UW.WAT2 (Waterville, WA, USA)
# 			UW.WATCH (Watch Mountain, Gifford Pinchot National Forest, WA, USA)
# 			UW.WHGC (Willapa Harbor Golf Course, WA, USA)
# 			UW.WINDI (Green Diamond Tree Farm, Mason County, WA, USA)
# 			UW.WISH (Wishka, WA, USA)
# 			UW.WPEQ (White Pass Ski Facility, WA, USA)
# 			UW.WRW (Wenatchee Ridge, WA, USA)
# 			UW.WYNO (Wynoochee Dam Area, Olympic National Forest, WA, USA)
# 			UW.YACT (Yacolt, WA, USA)
# 			UW.YELM (Yelm Schools Facilities and Maintenance, Yelm, WA, USA)
# 		Channels (396):
# 			UW.ABER..HHZ, UW.ABER..HHN, UW.ABER..HHE, UW.ANGUS..HHZ,
# 			UW.ANGUS..HHN, UW.ANGUS..HHE, UW.ARTIC..HHZ, UW.ARTIC..HHN,
# 			UW.ARTIC..HHE, UW.ASR2..HHZ, UW.ASR2..HHN, UW.ASR2..HHE,
# 			UW.BABR..HHZ, UW.BABR..HHN, UW.BABR..HHE, UW.BBO..HHZ, UW.BBO..HHN
# 			UW.BBO..HHE, UW.BDGR..HHZ, UW.BDGR..HHN, UW.BDGR..HHE,
# 			UW.BHAM..HHZ, UW.BHAM..HHN, UW.BHAM..HHE, UW.BHW..HHZ, UW.BHW..HHN
# 			UW.BHW..HHE, UW.BICK..HHZ, UW.BICK..HHN, UW.BICK..HHE,
# 			UW.BLOB..HHZ, UW.BLOB..HHN, UW.BLOB..HHE, UW.BLOW..HHZ,
# 			UW.BLOW..HHN, UW.BLOW..HHE, UW.BOIS..HHZ, UW.BOIS..HHN,
# 			UW.BOIS..HHE, UW.BRO..HHZ, UW.BRO..HHN, UW.BRO..HHE, UW.BST09..HHZ
# 			UW.BST09..HHN, UW.BST09..HHE, UW.BUCKS..HHZ, UW.BUCKS..HHN,
# 			UW.BUCKS..HHE, UW.CBS..HHZ, UW.CBS..HHN, UW.CBS..HHE, UW.CDF..HHZ,
# 			UW.CDF..HHN, UW.CDF..HHE, UW.CHIMA..HHZ, UW.CHIMA..HHN,
# 			UW.CHIMA..HHE, UW.CINE..HHZ, UW.CINE..HHN, UW.CINE..HHE,
# 			UW.CORE..HHZ, UW.CORE..HHN, UW.CORE..HHE, UW.COWL..HHZ,
# 			UW.COWL..HHN, UW.COWL..HHE, UW.COWS..HHZ, UW.COWS..HHN,
# 			UW.COWS..HHE, UW.COYL..HHZ, UW.COYL..HHN, UW.COYL..HHE,
# 			UW.CROWN..HHZ, UW.CROWN..HHN, UW.CROWN..HHE, UW.DART..HHZ,
# 			UW.DART..HHN, UW.DART..HHE, UW.DEAL..HHZ, UW.DEAL..HHN,
# 			UW.DEAL..HHE, UW.DONK..HHZ, UW.DONK..HHN, UW.DONK..HHE,
# 			UW.DOORS..HHZ, UW.DOORS..HHN, UW.DOORS..HHE, UW.DOSE..HHZ,
# 			UW.DOSE..HHN, UW.DOSE..HHE, UW.DOTY..HHZ, UW.DOTY..HHN,
# 			UW.DOTY..HHE, UW.EAGLE..HHZ, UW.EAGLE..HHN, UW.EAGLE..HHE,
# 			UW.EDM..HHZ, UW.EDM..HHN, UW.EDM..HHE, UW.EQUIL..HHZ, UW.EQUIL..HHN
# 			UW.EQUIL..HHE, UW.ETW..HHZ, UW.ETW..HHN, UW.ETW..HHE,
# 			UW.FISH2..HHZ, UW.FISH2..HHN, UW.FISH2..HHE, UW.FMW..HHZ,
# 			UW.FMW..HHN, UW.FMW..HHE, UW.FORK..HHZ, UW.FORK..HHN, UW.FORK..HHE
# 			UW.GIGA..HHZ, UW.GIGA..HHN, UW.GIGA..HHE, UW.GNW..HHZ,
# 			UW.GNW..HHN, UW.GNW..HHE, UW.GOLDN..HHZ, UW.GOLDN..HHN,
# 			UW.GOLDN..HHE, UW.GUEM..HHZ, UW.GUEM..HHN, UW.GUEM..HHE,
# 			UW.HANS..HHZ, UW.HANS..HHN, UW.HANS..HHE, UW.HDW..HHZ, UW.HDW..HHN
# 			UW.HDW..HHE, UW.HERD..HHZ, UW.HERD..HHN, UW.HERD..HHE,
# 			UW.HILL..HHZ, UW.HILL..HHN, UW.HILL..HHE, UW.HOOD..HHZ,
# 			UW.HOOD..HHN, UW.HOOD..HHE, UW.HOPR..HHZ, UW.HOPR..HHN,
# 			UW.HOPR..HHE, UW.HOQUI..HHZ, UW.HOQUI..HHN, UW.HOQUI..HHE,
# 			UW.HSR..HHZ, UW.HSR..HHN, UW.HSR..HHE, UW.HTW..HHZ, UW.HTW..HHN,
# 			UW.HTW..HHE, UW.INGAL..HHZ, UW.INGAL..HHN, UW.INGAL..HHE,
# 			UW.JEDS..HHZ, UW.JEDS..HHN, UW.JEDS..HHE, UW.KALA..HHZ,
# 			UW.KALA..HHN, UW.KALA..HHE, UW.KENT..HHZ, UW.KENT..HHN,
# 			UW.KENT..HHE, UW.KNGST..HHZ, UW.KNGST..HHN, UW.KNGST..HHE,
# 			UW.KREP..HHZ, UW.KREP..HHN, UW.KREP..HHE, UW.KTSAP..HHZ,
# 			UW.KTSAP..HHN, UW.KTSAP..HHE, UW.LACKA..HHZ, UW.LACKA..HHN,
# 			UW.LACKA..HHE, UW.LCCR..HHZ, UW.LCCR..HHN, UW.LCCR..HHE,
# 			UW.LEID..HHZ, UW.LEID..HHN, UW.LEID..HHE, UW.LOKMT..HHZ,
# 			UW.LOKMT..HHN, UW.LOKMT..HHE, UW.LON..HHZ (2x), UW.LON..HHN (2x),
# 			UW.LON..HHE (2x), UW.LOPEZ..HHZ, UW.LOPEZ..HHN, UW.LOPEZ..HHE,
# 			UW.LRIV..HHZ, UW.LRIV..HHN, UW.LRIV..HHE, UW.LTY..HHZ, UW.LTY..HHN
# 			UW.LTY..HHE, UW.LUMI..HHZ, UW.LUMI..HHN, UW.LUMI..HHE,
# 			UW.MANO..HHZ, UW.MANO..HHN, UW.MANO..HHE, UW.MAPLE..HHZ,
# 			UW.MAPLE..HHN, UW.MAPLE..HHE, UW.MBW2..HHZ, UW.MBW2..HHN,
# 			UW.MBW2..HHE, UW.MEW..HHZ, UW.MEW..HHN, UW.MEW..HHE, UW.MONTE..HHZ
# 			UW.MONTE..HHN, UW.MONTE..HHE, UW.MOODY..HHZ, UW.MOODY..HHN,
# 			UW.MOODY..HHE, UW.MOON..HHZ, UW.MOON..HHN, UW.MOON..HHE,
# 			UW.MORSE..HHZ, UW.MORSE..HHN, UW.MORSE..HHE, UW.MOX..HHZ,
# 			UW.MOX..HHN, UW.MOX..HHE, UW.MULN..HHZ, UW.MULN..HHN, UW.MULN..HHE
# 			UW.NATEM..HHZ, UW.NATEM..HHN, UW.NATEM..HHE, UW.NCO..HHZ,
# 			UW.NCO..HHN, UW.NCO..HHE, UW.NEL..HHZ, UW.NEL..HHN, UW.NEL..HHE,
# 			UW.NEMA..HHZ, UW.NEMA..HHN, UW.NEMA..HHE, UW.ODUC..HHZ,
# 			UW.ODUC..HHN, UW.ODUC..HHE, UW.OHOH..HHZ, UW.OHOH..HHN,
# 			UW.OHOH..HHE, UW.OLGA..HHZ, UW.OLGA..HHN, UW.OLGA..HHE,
# 			UW.OLQN..HHZ, UW.OLQN..HHN, UW.OLQN..HHE, UW.OQNOB..HHZ,
# 			UW.OQNOB..HHN, UW.OQNOB..HHE, UW.OSQM..HHZ, UW.OSQM..HHN,
# 			UW.OSQM..HHE, UW.OSR..HHZ, UW.OSR..HHN, UW.OSR..HHE, UW.OTR..HHZ,
# 			UW.OTR..HHN, UW.OTR..HHE, UW.PAN4H..HHZ, UW.PAN4H..HHN,
# 			UW.PAN4H..HHE, UW.PASS..HHZ, UW.PASS..HHN, UW.PASS..HHE,
# 			UW.PRIN..HHZ, UW.PRIN..HHN, UW.PRIN..HHE, UW.RADR..HHZ,
# 			UW.RADR..HHN, UW.RADR..HHE, UW.RATT..HHZ, UW.RATT..HHN,
# 			UW.RATT..HHE, UW.RCM..HHZ, UW.RCM..HHN, UW.RCM..HHE, UW.RER..HHZ,
# 			UW.RER..HHN, UW.RER..HHE, UW.RNWY..HHZ, UW.RNWY..HHN, UW.RNWY..HHE
# 			UW.RPW2..HHZ, UW.RPW2..HHN, UW.RPW2..HHE, UW.SALO..HHZ,
# 			UW.SALO..HHN, UW.SALO..HHE, UW.SAXON..HHZ, UW.SAXON..HHN,
# 			UW.SAXON..HHE, UW.SEAS2..HHZ, UW.SEAS2..HHN, UW.SEAS2..HHE,
# 			UW.SHUK..HHZ, UW.SHUK..HHN, UW.SHUK..HHE, UW.SHW..HHZ, UW.SHW..HHN
# 			UW.SHW..HHE, UW.SKAMO..HHZ, UW.SKAMO..HHN, UW.SKAMO..HHE,
# 			UW.SKOKO..HHZ, UW.SKOKO..HHN, UW.SKOKO..HHE, UW.SLDQ..HHZ,
# 			UW.SLDQ..HHN, UW.SLDQ..HHE, UW.SLF..HHZ, UW.SLF..HHN, UW.SLF..HHE,
# 			UW.SNAG..HHZ, UW.SNAG..HHN, UW.SNAG..HHE, UW.SP2..HHZ, UW.SP2..HHN
# 			UW.SP2..HHE, UW.SSO2..HHZ, UW.SSO2..HHN, UW.SSO2..HHE,
# 			UW.STOR..HHZ, UW.STOR..HHN, UW.STOR..HHE, UW.TBLMT..HHZ,
# 			UW.TBLMT..HHN, UW.TBLMT..HHE, UW.TDH..HHZ, UW.TDH..HHN, UW.TDH..HHE
# 			UW.TKEY..HHZ, UW.TKEY..HHN, UW.TKEY..HHE, UW.TOLE..HHZ,
# 			UW.TOLE..HHN, UW.TOLE..HHE, UW.TOLT..HHZ, UW.TOLT..HHN,
# 			UW.TOLT..HHE, UW.TOUT..HHZ, UW.TOUT..HHN, UW.TOUT..HHE,
# 			UW.TREE..HHZ, UW.TREE..HHN, UW.TREE..HHE, UW.TURTL..HHZ,
# 			UW.TURTL..HHN, UW.TURTL..HHE, UW.TWISP..HHZ, UW.TWISP..HHN,
# 			UW.TWISP..HHE, UW.VFP..HHZ, UW.VFP..HHN, UW.VFP..HHE, UW.WAT2..HHZ
# 			UW.WAT2..HHN, UW.WAT2..HHE, UW.WATCH..HHZ, UW.WATCH..HHN,
# 			UW.WATCH..HHE, UW.WHGC..HHZ, UW.WHGC..HHN, UW.WHGC..HHE,
# 			UW.WINDI..HHZ, UW.WINDI..HHN, UW.WINDI..HHE, UW.WISH..HHZ,
# 			UW.WISH..HHN, UW.WISH..HHE, UW.WPEQ..HHZ, UW.WPEQ..HHN,
# 			UW.WPEQ..HHE, UW.WRW..HHZ, UW.WRW..HHN, UW.WRW..HHE, UW.WYNO..HHZ,
# 			UW.WYNO..HHN, UW.WYNO..HHE, UW.YACT..HHZ, UW.YACT..HHN,
# 			UW.YACT..HHE, UW.YELM..HHZ, UW.YELM..HHN, UW.YELM..HHE

# %% [markdown]
# ## Visualizing the stations within the region to understand their distribution and coverage

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Extract station coordinates
stations = [(station.latitude, station.longitude) for network in inv for station in network.stations]

# Create a plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add geographic features
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Set the map bounds
ax.set_extent([min_longitude, max_longitude, min_latitude, max_latitude], crs=ccrs.PlateCarree())

# Plot the stations
if stations:
    lats, lons = zip(*stations)
    ax.scatter(lons, lats, color='red', marker='o', transform=ccrs.PlateCarree(), label='PNSN Stations')

# Add labels and title
ax.set_title('PNSN Stations in the Cascadia Subduction Zone')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# # 2. Phase Picking with PhaseNet (Seisbench)
#
#
# Using **PhaseNet** with **Seisbench** for phase picking significantly enhances earthquake detection by leveraging machine learning for precise seismic data analysis. PhaseNet, a pre-trained model available in Seisbench, automates the classification of seismic phases (P and S waves), which is crucial for accurate earthquake detection and analysis. The code demonstrates a workflow for using PhaseNet to classify seismic phases within a specified time window, utilizing parallel processing to handle large datasets efficiently.
#
# The code begins by setting up necessary imports and initializing the PhaseNet model. It defines a period of interest and extracts a list of stations from the inventory. A function **fetch_waveform_data** is created to fetch waveform data for a given station within a specified time window. The central processing loop iterates through each time window, fetching and combining waveform data from multiple stations concurrently using ThreadPoolExecutor. This parallel processing approach significantly speeds up data retrieval, using multiple CPU cores to handle the high volume of seismic data.
#
# Once the waveform data is retrieved, PhaseNet classifies the data to identify P and S wave picks. These picks are then added to a catalog, which is later fed into the associator for further analysis.

# %%
from obspy import UTCDateTime, Stream
import pandas as pd
from collections import Counter
import seisbench.models as sbm
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

picker = sbm.PhaseNet.from_pretrained("original")

# Initialize a single catalog for picks
pick_list = []

# Define start and end times for the period of interest
start_time = UTCDateTime("2024-07-11T00:00:00")
end_time = UTCDateTime("2024-07-13T00:00:00")
window_time = 7200  # Customize windows for fetching data

# Extract stations from the inventory
station_list = [{
    'Network': network.code,
    'Station': station.code
} for network in inv for station in network.stations]


# Function to fetch and filter waveform data for a given station
def fetch_waveform_data(station, current_time, window_time):
    try:
        stream = client.get_waveforms(
            network=station['Network'],
            station=station['Station'],
            location="*",
            channel="HH?",
            starttime=current_time,
            endtime=current_time + window_time
        )
        if stream:
            stream.detrend()  # Detrend before filtering
            stream.filter("highpass", freq=5)  # Apply highpass filter at 5 Hz
        return stream
    except Exception:
        return Stream()

# Loop through each time window
current_time = start_time

while current_time < end_time:
    combined_stream = Stream()
    
    # Measure the time taken to download data
    start_download_time = time.time()
    with ThreadPoolExecutor(max_workers=16) as executor:
        futures = [executor.submit(fetch_waveform_data, station, current_time, window_time) for station in station_list]
        for future in as_completed(futures):
            combined_stream += future.result()
    end_download_time = time.time()
    
    # Classify the combined stream using the PhaseNet picker if it is not empty
    if combined_stream:
        try:
            start_processing_time = time.time()
            picks = picker.classify(
                combined_stream, 
                batch_size=256, 
                P_threshold=0.075, 
                S_threshold=0.1
            ).picks
            end_processing_time = time.time()
            
            # Append picks to the catalog
            pick_list.extend([{
                "id": p.trace_id,
                "timestamp": p.peak_time.datetime,
                "prob": p.peak_value,
                "type": p.phase.lower()
            } for p in picks])
            
            # Print the count of P and S picks and the processing time
            pick_count = Counter(p.phase for p in picks)
            download_time = end_download_time - start_download_time
            processing_time = end_processing_time - start_processing_time
            print(f"Time window starting at {current_time}: {pick_count} (Download time: {download_time:.2f} seconds, Processing time: {processing_time:.2f} seconds)")
        
        except Exception as e:
            print(f"Error processing combined stream at {current_time}: {e}")
    
    # Move to the next time window
    current_time += window_time

# Convert the pick catalog to a DataFrame for further analysis or export
pick_df = pd.DataFrame(pick_list)

# Print the total number of picks
print(f"Total number of picks: {len(pick_df)}")
# Out:
# /srv/conda/envs/notebook/lib/python3.11/site-packages/seisbench/models/base.py:489: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_weights = torch.load(f"{path_pt}")
# Time window starting at 2024-07-11T00:00:00.000000Z: Counter({'P': 4148, 'S': 2958}) (Download time: 64.16 seconds, Processing time: 31.52 seconds)
# Time window starting at 2024-07-11T02:00:00.000000Z: Counter({'P': 3880, 'S': 2756}) (Download time: 39.29 seconds, Processing time: 31.60 seconds)
# Time window starting at 2024-07-11T04:00:00.000000Z: Counter({'P': 3547, 'S': 2592}) (Download time: 60.61 seconds, Processing time: 26.06 seconds)
# Time window starting at 2024-07-11T06:00:00.000000Z: Counter({'P': 2717, 'S': 1987}) (Download time: 59.71 seconds, Processing time: 24.27 seconds)
# Time window starting at 2024-07-11T08:00:00.000000Z: Counter({'P': 3043, 'S': 2233}) (Download time: 58.46 seconds, Processing time: 24.86 seconds)
# Time window starting at 2024-07-11T10:00:00.000000Z: Counter({'P': 4167, 'S': 3172}) (Download time: 37.00 seconds, Processing time: 24.63 seconds)
# Time window starting at 2024-07-11T12:00:00.000000Z: Counter({'P': 4596, 'S': 3481}) (Download time: 32.32 seconds, Processing time: 24.51 seconds)
# Time window starting at 2024-07-11T14:00:00.000000Z: Counter({'P': 5912, 'S': 4482}) (Download time: 67.93 seconds, Processing time: 24.64 seconds)
# Time window starting at 2024-07-11T16:00:00.000000Z: Counter({'P': 6068, 'S': 4654}) (Download time: 29.37 seconds, Processing time: 24.23 seconds)
# Time window starting at 2024-07-11T18:00:00.000000Z: Counter({'P': 5249, 'S': 3628}) (Download time: 62.99 seconds, Processing time: 24.75 seconds)
# Time window starting at 2024-07-11T20:00:00.000000Z: Counter({'P': 4816, 'S': 3229}) (Download time: 64.74 seconds, Processing time: 25.18 seconds)
# Time window starting at 2024-07-11T22:00:00.000000Z: Counter({'P': 4609, 'S': 3345}) (Download time: 23.31 seconds, Processing time: 24.70 seconds)
# Time window starting at 2024-07-12T00:00:00.000000Z: Counter({'P': 3761, 'S': 2670}) (Download time: 64.06 seconds, Processing time: 25.12 seconds)
# Time window starting at 2024-07-12T02:00:00.000000Z: Counter({'P': 4186, 'S': 3090}) (Download time: 60.90 seconds, Processing time: 25.03 seconds)
# Time window starting at 2024-07-12T04:00:00.000000Z: Counter({'P': 4000, 'S': 3113}) (Download time: 47.60 seconds, Processing time: 25.58 seconds)
# Time window starting at 2024-07-12T06:00:00.000000Z: Counter({'P': 3509, 'S': 2694}) (Download time: 35.96 seconds, Processing time: 24.51 seconds)
# Time window starting at 2024-07-12T08:00:00.000000Z: Counter({'P': 4103, 'S': 3233}) (Download time: 34.98 seconds, Processing time: 24.50 seconds)
# Time window starting at 2024-07-12T10:00:00.000000Z: Counter({'P': 4082, 'S': 3289}) (Download time: 34.86 seconds, Processing time: 24.76 seconds)
# Time window starting at 2024-07-12T12:00:00.000000Z: Counter({'P': 5217, 'S': 3962}) (Download time: 58.50 seconds, Processing time: 24.69 seconds)
# Time window starting at 2024-07-12T14:00:00.000000Z: Counter({'P': 5694, 'S': 4292}) (Download time: 36.03 seconds, Processing time: 24.52 seconds)
# Time window starting at 2024-07-12T16:00:00.000000Z: Counter({'P': 5488, 'S': 4114}) (Download time: 22.05 seconds, Processing time: 24.72 seconds)
# Time window starting at 2024-07-12T18:00:00.000000Z: Counter({'P': 5034, 'S': 3607}) (Download time: 62.18 seconds, Processing time: 24.20 seconds)
# Time window starting at 2024-07-12T20:00:00.000000Z: Counter({'P': 4426, 'S': 3237}) (Download time: 61.76 seconds, Processing time: 24.52 seconds)
# Time window starting at 2024-07-12T22:00:00.000000Z: Counter({'P': 4167, 'S': 3106}) (Download time: 61.92 seconds, Processing time: 24.58 seconds)
# Total number of picks: 185343

# %% [markdown]
# # 3. Phase Association with PyOcto
#
# PyOcto is a high-throughput seismic phase associator that efficiently links seismic phases to specific earthquake events, accurately determining their locations and origin times. It utilizes a 4D space-time partitioning method, starting with a large node that spans the entire study area and iteratively refines potential earthquake locations by splitting nodes based on the highest number of picks. This process is managed using a priority queue system, enhancing processing speed by discarding non-promising nodes early. PyOcto supports homogeneous and 1D velocity models and allows for customizable parameters for multi-region studies.
#
# **Note: PyOcto outputs locations, but these are meant to be initial sources. Further refinement of locations is needed for accurate locations.**

# %% [markdown]
# ### Associator Configurations

# %%
import pyocto

# Define the velocity model with specified parameters
velocity_model = pyocto.VelocityModel0D(
    p_velocity=7.0,
    s_velocity=4.0,
    tolerance=2.0,
    association_cutoff_distance=300,
)

# Create the associator with corrected latitude and longitude ranges
associator = pyocto.OctoAssociator.from_area(
    lat=(40, 55),  
    lon=(-135, -120),  
    zlim=(0, 200),
    time_before=300,
    velocity_model=velocity_model,
    n_picks=6,
    n_p_and_s_picks=3,
)

# Convert station information to the required format
stations = associator.inventory_to_df(inv)

# %% [markdown]
# ### Association

# %%
# Perform the phase association 
events, assignments = associator.associate_seisbench(picks, stations)

# Transform event coordinates back to latitude and longitude
associator.transform_events(events)
# Out:
#     idx          time           x           y          z  picks   latitude  \
# 0     0  1.720822e+09  535.019439  -25.848455   4.296875      8  47.050492
# 1     1  1.720822e+09  386.090051   -5.176223   3.515625      9  47.339431
# 2     2  1.720823e+09  401.108141   49.398470   0.390625      8  47.819146
# 3     3  1.720823e+09  423.635275  134.568066   0.390625      7  48.566905
# 4     4  1.720823e+09  331.023723   70.897591   0.390625      7  48.051757
# 5     5  1.720824e+09  264.693828   -6.830001   0.390625      6  47.384935
# 6     6  1.720824e+09  462.432006  -48.174465   0.390625      9  46.905487
# 7     7  1.720825e+09  255.933275   67.590034   0.390625      6  48.056570
# 8     8  1.720825e+09  327.269201   45.264024   5.859375      6  47.823825
# 9     9  1.720825e+09  307.245081  -49.828244   0.390625      7  46.980540
# 10   10  1.720826e+09  257.184783   52.706027   0.390625      7  47.922449
# 11   11  1.720826e+09  454.922961 -220.994325   0.390625      7  45.364099
# 12   12  1.720827e+09  421.132260  185.835201  12.109375     11  49.027290
# 13   13  1.720827e+09  454.922961  -23.367787  24.609375      6  47.132582
# 14   14  1.720827e+09  416.126230  -45.693797  15.234375      9  46.958275
# 15   15  1.720827e+09  343.538797   43.610245   0.390625      6  47.800530
# 16   16  1.720827e+09  -25.655903  239.583004  99.609375     13  49.653949
# 17   17  1.720827e+09  192.106395   33.687574  33.203125     15  47.774363
# 18   18  1.720827e+09  252.178753   32.860684   0.390625     25  47.746259
# 19   19  1.720827e+09  263.442320   -7.656890   0.390625     15  47.378017
# 20   20  1.720828e+09  305.993574  -86.211372   0.390625      7  46.654638
# 21   21  1.720828e+09  290.975484   48.571581   0.390625      7  47.870925
# 22   22  1.720828e+09  232.154634   13.015342  14.453125     12  47.575538
# 23   23  1.720828e+09  259.687798   -5.176223   0.390625     12  47.401790
# 24   24  1.720829e+09  494.971200 -178.822971  86.328125     11  45.714147
#
#      longitude      depth
# 0  -120.457533   4.296875
# 1  -122.390612   3.515625
# 2  -122.142969   0.390625
# 3  -121.758808   0.390625
# 4  -123.059278   0.390625
# 5  -123.994314   0.390625
# 6  -121.429785   0.390625
# 7  -124.066452   0.390625
# 8  -123.128948   5.859375
# 9  -123.461515   0.390625
# 10 -124.058599   0.390625
# 11 -121.693276   0.390625
# 12 -121.740100  12.109375
# 13 -121.502912  24.609375
# 14 -122.032374  15.234375
# 15 -122.913660   0.390625
# 16 -127.855301  99.609375
# 17 -124.936797  33.203125
# 18 -124.137010   0.390625
# 19 -124.011348   0.390625
# 20 -123.502234   0.390625
# 21 -123.610245   0.390625
# 22 -124.414159  14.453125
# 23 -124.059524   0.390625
# 24 -121.142576  86.328125

# %% [markdown]
# # 4. Visualize the Results

# %% [markdown]
# ## Map View of Located Events

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

min_latitude = 41.0
max_latitude = 54.0
min_longitude = -132.0
max_longitude = -118.0

# Extract station coordinates
stations = [(station.latitude, station.longitude) for network in inv for station in network.stations]

# Extract event coordinates
event_lats = events['latitude'].tolist()
event_lons = events['longitude'].tolist()

# Create a plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Add geographic features
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linestyle=':')

# Set the map bounds
ax.set_extent([min_longitude, max_longitude, min_latitude, max_latitude], crs=ccrs.PlateCarree())

# Plot the stations
if stations:
    lats, lons = zip(*stations)
    ax.scatter(lons, lats, color='red', marker='o',s=10, transform=ccrs.PlateCarree(), label='PNSN Stations')

# Plot the earthquake events
ax.scatter(event_lons, event_lats, color='blue', marker='x',s=12, transform=ccrs.PlateCarree(), label='Earthquake Events')

# Add labels and title
ax.set_title('Earthquake Events in the Cascadia Subduction Zone')
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Inspect Some Events (Waveforms)

# %%
import numpy as np
import obspy
import matplotlib.pyplot as plt

# Plotting the event and picks as per the initial code
event_idx = np.random.choice(events["idx"])
event_picks = [picks[i] for i in assignments[assignments["event_idx"] == event_idx]["pick_idx"]]
event = events[events["idx"] == event_idx].iloc[0]

station_dict = {station: (x, y) for station, x, y in zip(stations_df["id"], stations_df["x"], stations_df["y"])}

first, last = min(pick.peak_time for pick in event_picks), max(pick.peak_time for pick in event_picks)

sub = obspy.Stream()

for station in np.unique([pick.trace_id for pick in event_picks]):
    sub.append(combined_stream.select(station=station.split('.')[1], channel="HHZ")[0])

sub = sub.slice(first - 5, last + 5)

sub = sub.copy()
sub.detrend()
sub.filter("highpass", freq=5)

fig, axs = plt.subplots(len(sub), 1, figsize=(10, len(sub) * 1.5), sharex=True)

if len(sub) == 1:
    axs = [axs]

for i, trace in enumerate(sub):
    normed = trace.data - np.mean(trace.data)
    normed = normed / np.max(np.abs(normed))
    station_x, station_y = station_dict[trace.id.split('.')[1]]
    y = np.sqrt((station_x - event["x"]) ** 2 + (station_y - event["y"]) ** 2 + event["z"] ** 2)
    
    axs[i].plot(trace.times(), normed, color='royalblue')  # Set waveform color to dark gray
    axs[i].set_xlim(0, trace.times()[-1])  # Adjust x-axis limits to trace start and end times
    axs[i].set_ylabel(f"{y:.2f} km")
    axs[i].yaxis.set_ticks([])  # Remove y-axis ticks
    axs[i].tick_params(axis='y', which='both', length=0)  # Remove y-axis tick marks
    
    for pick in event_picks:
        if pick.trace_id.split('.')[1] == trace.id.split('.')[1]:
            x = pick.peak_time - trace.stats.starttime
            if pick.phase == "P":
                ls = '-'
            else:
                ls = '--'
            axs[i].axvline(x=x, color='k', linestyle=ls)

axs[-1].set_xlabel("Time [s]")

# Manually adjust the spacing between subplots
plt.subplots_adjust(hspace=0)
plt.show()

print("Event information")
print(event)
# Out:
# Event information
# idx          1.900000e+01
# time         1.720827e+09
# x            2.634423e+02
# y           -7.656890e+00
# z            3.906250e-01
# picks        1.500000e+01
# latitude     4.737802e+01
# longitude   -1.240113e+02
# depth        3.906250e-01
# Name: 19, dtype: float64
